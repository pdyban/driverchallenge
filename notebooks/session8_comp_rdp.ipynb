# %%
pathToDriverData = '../../drivers_npy/'
pathToSpeedData = '../../speed_npy/'
pathToCurveData = '../../curve_npy/'

import DriverChallengeHelperFunctions as helpers
import DriverDataIO as io
import DriverChallengeVisualization as vis
import sys

sys.path.append("../../RDP/")

rdp = __import__("rdp")

# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

# %%
driverNum = 1;
tripNum = 1;

# %%
trip = io.get_trip_npy(driverNum, tripNum, pathToDriverData)

# %%
vis.plot_speed(trip)

# %%
len(trip)
# Out:
# 863

# %%
rdpTrip = rdp.rdp(trip, 1)

# %%
vis.plot_speed(rdpTrip)

# %%
len(rdpTrip)
# Out:
# 201
